# %% [markdown]
# # VERSIÓN 6

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import time
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.utils import to_categorical

# %%
# Se cargan las imágenes del dataset MNIST
(training_images, training_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path="mnist.npz")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# Función que visualiza un ejemplo
def visualize(sample):
  image = training_images[sample]
  fig = plt.figure
  plt.imshow(image.reshape(28,28), cmap='gray')
  plt.show()

# %% [markdown]
# ## PREPARACIÓN DE LOS DATOS

# %%
# Se cambia el tipo de los datos a float32
training_images = training_images.astype("float32")
test_images = test_images.astype("float32")

# Las imágenes pasan de matriz 28x28 a vector 784x1
training_images = training_images.reshape(training_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# Normalización: los datos pasan a tener un valor entre [0, 1]
training_images = training_images / 255
test_images = test_images / 255

# %% [markdown]
# ## CONJUNTO DE VALIDACIÓN

# %%
# Se separa en un conjunto de validación y de entrenamiento
validation_images = training_images[-10000:]
validation_labels = training_labels[-10000:]

training_images = training_images[:50000]
training_labels = training_labels[:50000]

# %% [markdown]
# ## ENTRENAMIENTO

# %%
model = Sequential()

# Se añaden las capas
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(32, kernel_size=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(64, kernel_size=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Se compila el modelo
hist = model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Se entrena el modelo
start = time.time()

hist = model.fit(
  training_images,
  to_categorical(training_labels),
  epochs=35,
  batch_size=64,
  validation_data=(validation_images,to_categorical(validation_labels)),
)

end = time.time()

# Se evalua la red neuronal
eval = model.evaluate(
  test_images,
  to_categorical(test_labels)
)
# Out:
# Epoch 1/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.2874 - accuracy: 0.9082 - val_loss: 0.0597 - val_accuracy: 0.9825
# Epoch 2/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0983 - accuracy: 0.9698 - val_loss: 0.0455 - val_accuracy: 0.9863
# Epoch 3/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0759 - accuracy: 0.9770 - val_loss: 0.0420 - val_accuracy: 0.9885
# Epoch 4/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0649 - accuracy: 0.9801 - val_loss: 0.0345 - val_accuracy: 0.9900
# Epoch 5/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0562 - accuracy: 0.9827 - val_loss: 0.0375 - val_accuracy: 0.9900
# Epoch 6/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0551 - accuracy: 0.9829 - val_loss: 0.0370 - val_accuracy: 0.9897
# Epoch 7/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0489 - accuracy: 0.9847 - val_loss: 0.0278 - val_accuracy: 0.9925
# Epoch 8/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0446 - accuracy: 0.9857 - val_loss: 0.0280 - val_accuracy: 0.9925
# Epoch 9/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0399 - accuracy: 0.9876 - val_loss: 0.0302 - val_accuracy: 0.9922
# Epoch 10/35
# 782/782 [==============================] - 61s 77ms/step - loss: 0.0378 - accuracy: 0.9884 - val_loss: 0.0323 - val_accuracy: 0.9915
# Epoch 11/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0377 - accuracy: 0.9886 - val_loss: 0.0325 - val_accuracy: 0.9912
# Epoch 12/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0334 - accuracy: 0.9899 - val_loss: 0.0267 - val_accuracy: 0.9926
# Epoch 13/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0340 - accuracy: 0.9893 - val_loss: 0.0282 - val_accuracy: 0.9923
# Epoch 14/35
# 782/782 [==============================] - 62s 80ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.0300 - val_accuracy: 0.9924
# Epoch 15/35
# 782/782 [==============================] - 61s 77ms/step - loss: 0.0316 - accuracy: 0.9906 - val_loss: 0.0320 - val_accuracy: 0.9926
# Epoch 16/35
# 782/782 [==============================] - 60s 77ms/step - loss: 0.0303 - accuracy: 0.9905 - val_loss: 0.0266 - val_accuracy: 0.9931
# Epoch 17/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0272 - val_accuracy: 0.9919
# Epoch 18/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0266 - accuracy: 0.9914 - val_loss: 0.0252 - val_accuracy: 0.9937
# Epoch 19/35
# 782/782 [==============================] - 62s 80ms/step - loss: 0.0263 - accuracy: 0.9915 - val_loss: 0.0265 - val_accuracy: 0.9933
# Epoch 20/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0276 - accuracy: 0.9919 - val_loss: 0.0259 - val_accuracy: 0.9930
# Epoch 21/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.0327 - val_accuracy: 0.9913
# Epoch 22/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0320 - val_accuracy: 0.9920
# Epoch 23/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.0272 - val_accuracy: 0.9942
# Epoch 24/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.0249 - val_accuracy: 0.9937
# Epoch 25/35
# 782/782 [==============================] - 61s 79ms/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 0.0284 - val_accuracy: 0.9932
# Epoch 26/35
# 782/782 [==============================] - 61s 79ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.0309 - val_accuracy: 0.9926
# Epoch 27/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0283 - val_accuracy: 0.9936
# Epoch 28/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0288 - val_accuracy: 0.9926
# Epoch 29/35
# 782/782 [==============================] - 63s 80ms/step - loss: 0.0206 - accuracy: 0.9936 - val_loss: 0.0304 - val_accuracy: 0.9928
# Epoch 30/35
# 782/782 [==============================] - 61s 78ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.0323 - val_accuracy: 0.9925
# Epoch 31/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0292 - val_accuracy: 0.9934
# Epoch 32/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.0274 - val_accuracy: 0.9935
# Epoch 33/35
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.0294 - val_accuracy: 0.9937
# Epoch 34/35
# 782/782 [==============================] - 64s 81ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 0.0252 - val_accuracy: 0.9940
# Epoch 35/35
# 782/782 [==============================] - 62s 80ms/step - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.0262 - val_accuracy: 0.9933
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9953

# %% [markdown]
# ## PORCENTAJE DE ERROR

# %%
accuracy_val = eval[1]
error_val = (1 - accuracy_val)*100

accuracy_train = hist.history['accuracy'][-1]
error_train = (1 - accuracy_train)*100

print("Porcentaje de error sobre el conjunto de entrenamiento: "+str(round(error_train,2)))
print("Porcentaje de error sobre el conjunto de prueba: "+str(round(error_val,2)))
print("Tiempo transcurrido: "+str(round(end - start,2)))

epochs = range(len(hist.history['accuracy']))
loss = hist.history['loss']
loss_val = hist.history['val_loss']
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, loss_val, 'r', label='Validation loss')
plt.title("Loss")
plt.legend()
plt.show()
accuracy = hist.history['accuracy']
accuracy_val = hist.history['val_accuracy']
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'r', label='Validation accuracy')
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# Porcentaje de error sobre el conjunto de entrenamiento: 0.61
# Porcentaje de error sobre el conjunto de prueba: 0.47
# Tiempo transcurrido: 2151.15

# %% [markdown]
# ## VISUALIZACIÓN DE LA RED

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
